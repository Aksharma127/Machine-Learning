# %% [markdown]
# <a href="https://colab.research.google.com/github/Aksharma127/Machine-Learning/blob/main/polinomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Polynomial Linear Regression
# y= b_{0} + b_{1}*x_{1} + b_{2} * x_{1} ^ 2 +...+b n x 1 ^ n

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from re import X
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression ()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y,color = 'red')
plt.plot(X,lin_reg_2.predict(X_poly),color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
