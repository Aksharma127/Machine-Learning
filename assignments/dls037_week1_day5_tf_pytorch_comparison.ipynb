# %% [markdown]
# # Week1-Day5 Assignment**Name:** Akshit Sharma**Roll No.:** 25DLS037

# %% [markdown]
# ##Task 1 (5 Marks) – TensorFlow (Keras backend):

# %%
import tensorflow as tf# Input (manually set)X = tf.constant([[0.5, -1.5, 2.0]], dtype=tf.float32)# Manually setting weights and biasW = tf.Variable([[0.2], [0.8], [-0.5]], dtype=tf.float32)b = tf.Variable(0.1, dtype=tf.float32)# z = XW + bz = tf.matmul(X, W) + b# Sigmoid activationa = tf.math.sigmoid(z)# True labely_true = tf.constant([[1.0]], dtype=tf.float32)# Manually calculating Binary Cross-Entropy Lossepsilon = 1e-7loss = -(y_true * tf.math.log(a + epsilon) + (1 - y_true) * tf.math.log(1 - a + epsilon))print("TensorFlow")print("z:", z.numpy())print("sigmoid(z):", a.numpy())print("Binary Cross-Entropy Loss:", loss.numpy())
# Out:
# TensorFlow
# z: [[-1.9999999]]
# sigmoid(z): [[0.11920293]]
# Binary Cross-Entropy Loss: [[2.1269271]]

# %% [markdown]
# ##Task 2 (5 Marks) – PyTorch:

# %%
import torch# Input (manual)X = torch.tensor([[0.5, -1.5, 2.0]], dtype=torch.float32)# Weights and bias (manual, requires_grad for backprop)W = torch.tensor([[0.2], [0.8], [-0.5]], dtype=torch.float32, requires_grad=True)b = torch.tensor(0.1, dtype=torch.float32, requires_grad=True)# z = XW + bz = torch.mm(X, W) + b# Sigmoida = torch.sigmoid(z)# True labely_true = torch.tensor([[1.0]], dtype=torch.float32)# Manually calculating lossepsilon = 1e-7loss = -(y_true * torch.log(a + epsilon) + (1 - y_true) * torch.log(1 - a + epsilon))# Backward passloss.backward()print("\nPyTorch")print("z:", z.detach().numpy())print("sigmoid(z):", a.detach().numpy())print("Binary Cross-Entropy Loss:", loss.item())print("Gradients for W:", W.grad)print("Gradient for b:", b.grad)
# Out:
# PyTorch
# z: [[-1.9999999]]
# sigmoid(z): [[0.11920293]]
# Binary Cross-Entropy Loss: 2.126927137374878
# Gradients for W: tensor([[-0.4404],
#         [ 1.3212],
#         [-1.7616]])
# Gradient for b: tensor(-0.8808)
