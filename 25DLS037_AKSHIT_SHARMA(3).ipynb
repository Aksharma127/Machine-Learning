# %% [markdown]
# # DL - Summer Camp Assignment - Week 1
# **Name:** Akshit Sharma
# **Roll No.:** 25DLS037

# %% [markdown]
# ## Q1: Introduction to AI/ML/DL [1 mark]

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Logistic Regression
lr = LogisticRegression(max_iter=200)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# Neural Net
mlp = MLPClassifier(hidden_layer_sizes=(10,), max_iter=1000)
mlp.fit(X_train, y_train)
mlp_pred = mlp.predict(X_test)
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Logistic Regression
lr = LogisticRegression(max_iter=200)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# Neural Net
mlp = MLPClassifier(hidden_layer_sizes=(10,), max_iter=1000)
mlp.fit(X_train, y_train)
mlp_pred = mlp.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, lr_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, lr_pred))

print("\nDecision Tree Accuracy:", accuracy_score(y_test, dt_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, dt_pred))

print("\nNeural Network Accuracy:", accuracy_score(y_test, mlp_pred))
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Logistic Regression
lr = LogisticRegression(max_iter=200)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# Neural Net
mlp = MLPClassifier(hidden_layer_sizes=(10,), max_iter=1000)
mlp.fit(X_train, y_train)
mlp_pred = mlp.predict(X_test)
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Logistic Regression
lr = LogisticRegression(max_iter=200)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# Neural Net
mlp = MLPClassifier(hidden_layer_sizes=(10,), max_iter=1000)
mlp.fit(X_train, y_train)
mlp_pred = mlp.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, lr_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, lr_pred))

print("\nDecision Tree Accuracy:", accuracy_score(y_test, dt_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, dt_pred))

print("\nNeural Network Accuracy:", accuracy_score(y_test, mlp_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, mlp_pred))
print("\nDecision Tree Accuracy:", accuracy_score(y_test, dt_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, dt_pred))

# Corrected the variable name from ml_pred to mlp_pred
print("\nNeural Network Accuracy:", accuracy_score(y_test, mlp_pred))
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Logistic Regression
lr = LogisticRegression(max_iter=200)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# Neural Net
mlp = MLPClassifier(hidden_layer_sizes=(10,), max_iter=1000)
mlp.fit(X_train, y_train)
mlp_pred = mlp.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, lr_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, lr_pred))

print("\nDecision Tree Accuracy:", accuracy_score(y_test, dt_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, dt_pred))

print("\nNeural Network Accuracy:", accuracy_score(y_test, mlp_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, mlp_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Logistic Regression Accuracy: 0.9333333333333333
# Confusion Matrix:
#  [[ 9  0  0]
#  [ 0 10  2]
#  [ 0  0  9]]
#
# Decision Tree Accuracy: 0.9333333333333333
# Confusion Matrix:
#  [[ 9  0  0]
#  [ 0 10  2]
#  [ 0  0  9]]
#
# Neural Network Accuracy: 0.9333333333333333
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# **Comment:**
# The neural net uses nonlinear activation and layered representation, so it's capable of capturing more complex patterns than Logistic Regression or Decision Tree, though it might overfit or require tuning.

# %% [markdown]
# ## Q2: Mathematics for Deep Learning [4 marks]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Matrix operations
A = np.array([[1, 2, 3], [0, 1, 4], [5, 6, 0]])
B = np.dot(A, A)
det = np.linalg.det(A)
inv = np.linalg.inv(A) if det != 0 else "No Inverse"

import numpy as np
import matplotlib.pyplot as plt

# Matrix operations
A = np.array([[1, 2, 3], [0, 1, 4], [5, 6, 0]])
B = np.dot(A, A)
det = np.linalg.det(A)
inv = np.linalg.inv(A) if det != 0 else "No Inverse"

eigvals, eigvecs = np.linalg.eig(A)

print("A*A:\n", B)
print("Determinant:", det)
print("Inverse:\n", inv)
print("Eigenvalues:", eigvals)
print("Eigenvectors:\n", eigvecs)

# Plot f(x) = x^2 + 3x + 2 and derivative
x = np.linspace(-10, 10, 200)
f = x**2 + 3*x + 2
df = 2*x + 3

plt.plot(x, f, label="f(x)")
plt.plot(x, df, label="f'(x)")
plt.legend()
plt.title("Function and Derivative")
plt.grid(True)
plt.show()

# Sigmoid and its derivative
sigmoid = 1 / (1 + np.exp(-x))
dsigmoid = sigmoid * (1 - sigmoid)

plt.plot(x, sigmoid, label="σ(x)")
plt.plot(x, dsigmoid, label="σ'(x)")
plt.legend()
plt.title("Sigmoid and Derivative")
plt.grid(True)
plt.show()

# Probability Distributions
P = np.array([0.2, 0.5, 0.3])
Q = np.array([1/3, 1/3, 1/3])
cross_entropy = -np.sum(P * np.log(Q))
kl_div = np.sum(P * np.log(P / Q))

import numpy as np
import matplotlib.pyplot as plt

# Matrix operations
A = np.array([[1, 2, 3], [0, 1, 4], [5, 6, 0]])
B = np.dot(A, A)
det = np.linalg.det(A)
inv = np.linalg.inv(A) if det != 0 else "No Inverse"

eigvals, eigvecs = np.linalg.eig(A)

print("A*A:\n", B)
print("Determinant:", det)
print("Inverse:\n", inv)
print("Eigenvalues:", eigvals)
print("Eigenvectors:\n", eigvecs)

# Plot f(x) = x^2 + 3x + 2 and derivative
x = np.linspace(-10, 10, 200)
f = x**2 + 3*x + 2
df = 2*x + 3

plt.plot(x, f, label="f(x)")
plt.plot(x, df, label="f'(x)")
plt.legend()
plt.title("Function and Derivative")
plt.grid(True)
plt.show()

# Sigmoid and its derivative
sigmoid = 1 / (1 + np.exp(-x))
dsigmoid = sigmoid * (1 - sigmoid)

plt.plot(x, sigmoid, label="σ(x)")
plt.plot(x, dsigmoid, label="σ'(x)")
plt.legend()
plt.title("Sigmoid and Derivative")
plt.grid(True)
plt.show()

# Probability Distributions
P = np.array([0.2, 0.5, 0.3])
Q = np.array([1/3, 1/3, 1/3])
cross_entropy = -np.sum(P * np.log(Q))
kl_div = np.sum(P * np.log(P / Q))

import numpy as np
import matplotlib.pyplot as plt

# Matrix operations
A = np.array([[1, 2, 3], [0, 1, 4], [5, 6, 0]])
B = np.dot(A, A)
det = np.linalg.det(A)
inv = np.linalg.inv(A) if det != 0 else "No Inverse"

eigvals, eigvecs = np.linalg.eig(A)

print("A*A:\n", B)
print("Determinant:", det)
print("Inverse:\n", inv)
print("Eigenvalues:", eigvals)
print("Eigenvectors:\n", eigvecs)

# Plot f(x) = x^2 + 3x + 2 and derivative
x = np.linspace(-10, 10, 200)
f = x**2 + 3*x + 2
df = 2*x + 3

plt.plot(x, f, label="f(x)")
plt.plot(x, df, label="f'(x)")
plt.legend()
plt.title("Function and Derivative")
plt.grid(True)
plt.show()

# Sigmoid and its derivative
sigmoid = 1 / (1 + np.exp(-x))
dsigmoid = sigmoid * (1 - sigmoid)

plt.plot(x, sigmoid, label="σ(x)")
plt.plot(x, dsigmoid, label="σ'(x)")
plt.legend()
plt.title("Sigmoid and Derivative")
plt.grid(True)
plt.show()

# Probability Distributions
P = np.array([0.2, 0.5, 0.3])
Q = np.array([1/3, 1/3, 1/3])
cross_entropy = -np.sum(P * np.log(Q))
kl_div = np.sum(P * np.log(P / Q))

print("Cross Entropy:", cross_entropy)
print("KL Divergence:", kl_div)
# Plot f(x) = x^2 + 3x + 2 and derivative
x = np.linspace(-10, 10, 200)
f = x**2 + 3*x + 2
df = 2*x + 3

plt.plot(x, f, label="f(x)")
plt.plot(x, df, label="f'(x)")
plt.legend()
plt.title("Function and Derivative")
plt.grid(True)
plt.show()

# Sigmoid and its derivative
sigmoid = 1 / (1 + np.exp(-x))
dsigmoid = sigmoid * (1 - sigmoid)

plt.plot(x, sigmoid, label="σ(x)")
plt.plot(x, dsigmoid, label="σ'(x)")
plt.legend()
plt.title("Sigmoid and Derivative")
plt.grid(True)
plt.show()

# Probability Distributions
P = np.array([0.2, 0.5, 0.3])
Q = np.array([1/3, 1/3, 1/3])
cross_entropy = -np.sum(P * np.log(Q))
kl_div = np.sum(P * np.log(P / Q))

print("Cross Entropy:", cross_entropy)
print("KL Divergence:", kl_div)
# Out:
# A*A:
#  [[16 22 11]
#  [20 25  4]
#  [ 5 16 39]]
# Determinant: 0.9999999999999964
# Inverse:
#  [[-24.  18.   5.]
#  [ 20. -15.  -4.]
#  [ -5.   4.   1.]]
# Eigenvalues: [-5.2296696  -0.02635282  7.25602242]
# Eigenvectors:
#  [[ 0.22578016 -0.75769839 -0.49927017]
#  [ 0.52634845  0.63212771 -0.46674201]
#  [-0.81974424 -0.16219652 -0.72998712]]
# A*A:
#  [[16 22 11]
#  [20 25  4]
#  [ 5 16 39]]
# Determinant: 0.9999999999999964
# Inverse:
#  [[-24.  18.   5.]
#  [ 20. -15.  -4.]
#  [ -5.   4.   1.]]
# Eigenvalues: [-5.2296696  -0.02635282  7.25602242]
# Eigenvectors:
#  [[ 0.22578016 -0.75769839 -0.49927017]
#  [ 0.52634845  0.63212771 -0.46674201]
#  [-0.81974424 -0.16219652 -0.72998712]]
# A*A:
#  [[16 22 11]
#  [20 25  4]
#  [ 5 16 39]]
# Determinant: 0.9999999999999964
# Inverse:
#  [[-24.  18.   5.]
#  [ 20. -15.  -4.]
#  [ -5.   4.   1.]]
# Eigenvalues: [-5.2296696  -0.02635282  7.25602242]
# Eigenvectors:
#  [[ 0.22578016 -0.75769839 -0.49927017]
# ...
